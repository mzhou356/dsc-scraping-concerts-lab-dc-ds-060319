# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
import re
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
#Load the https://www.residentadvisor.net/events page in your browser.
response = requests.get("https://www.residentadvisor.net/events/us/newyork")
soup = BeautifulSoup(response.content, 'html.parser')

# %%
event_listings = soup.find('div', id="event-listing")

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
entries = event_listings.find_all('li')

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    event_listings = soup.find('div', id="event-listing")
    entries = event_listings.find_all('li')
    rows = []
    for entry in entries:
        #Is it a date? If so, set current date.
        date = entry.find('p', class_="eventDate date")
        event = entry.find('h1', class_="event-title")
        if event:
            details = event.text.split(' at ')
            event_name = details[0].strip()
            venue = details[1].strip()
            try:
                n_attendees = int(re.match("(\d*)", entry.find('p', class_="attending").text)[0])
            except:
                n_attendees = np.nan
            rows.append([event_name, venue, cur_date, n_attendees])
        elif date:
            cur_date = date.text
        else:
            continue
    return rows
scrape_events(events_page_url)
# Out:
# [['Body Music Therapy with Nihal Ramchandani',
#   'Nowadays',
#   'Tue, 25 Jun 2019 /',
#   17],
#  ['Techno BUS presents: Aggressive School Nite',
#   'Jupiter Disco',
#   'Tue, 25 Jun 2019 /',
#   9],
#  ['Cheers Bklyn 25', 'TBA Brooklyn', 'Tue, 25 Jun 2019 /', 8],
#  ['New World Dysorder: A Riot', 'Bossa', 'Tue, 25 Jun 2019 /', 3],
#  ['Forbidden Colors', 'public records', 'Tue, 25 Jun 2019 /', nan],
#  ['Feel Real with DJ Disciple, Ejoe Wilson Friends',
#   'Rumpus Room',
#   'Tue, 25 Jun 2019 /',
#   nan],
#  ['Exotic House Party with Animal Feelings (Live) and Kristine Barilli (DJ)',
#   'Elsewhere',
#   'Tue, 25 Jun 2019 /',
#   nan],
#  ['Prefuse 73', 'Le Poisson Rouge', 'Wed, 26 Jun 2019 /', 5],
#  ['Pure Immanence Xxxv', 'Bossa Nova Civic Club', 'Wed, 26 Jun 2019 /', 18],
#  ['Nicky Siano - Live Podcast Launch', 'Good Room', 'Wed, 26 Jun 2019 /', 7],
#  ['Funk You', 'House Of Yes', 'Wed, 26 Jun 2019 /', 7],
#  ['Omni Assembly', 'Good Room', 'Wed, 26 Jun 2019 /', nan],
#  ['Ūndisclosed - Nu Sky, Mitchell Frederick, Alex Fogo, Diegomystick',
#   'TBA Brooklyn',
#   'Wed, 26 Jun 2019 /',
#   nan],
#  ['Alisaloog', 'Elsewhere', 'Wed, 26 Jun 2019 /', nan],
#  ['Basside, Tama Gucci, Flor2k, DRUMMy',
#   'Elsewhere',
#   'Wed, 26 Jun 2019 /',
#   nan],
#  ['Open Decks Session 69', 'Eris', 'Wed, 26 Jun 2019 /', nan],
#  ['2RU Deep NYC', 'Rumpus Room', 'Wed, 26 Jun 2019 /', nan],
#  ['Come One, Come Ally', 'The Woods', 'Wed, 26 Jun 2019 /', nan],
#  ["Expansions NYC-Celebrates World Pride Pride's 50th",
#   'Doux',
#   'Wed, 26 Jun 2019 /',
#   nan],
#  ['Expansions NYC Special Pride Party Guests Toni C., Jihad Muhammad, and Ritmao y Tumbao',
#   'Doux Supper Club',
#   'Wed, 26 Jun 2019 /',
#   nan],
#  ['Morgana [free entry]: Matthias Meyer, Jonas Rathsman, Patlac, Steve Graham',
#   'Brooklyn Mirage',
#   'Thu, 27 Jun 2019 /',
#   422],
#  ['Harder NYC World Pride 2019', 'Schimanski', 'Thu, 27 Jun 2019 /', 169],
#  ['A Club Called Rhonda NYC World Pride: A Deeper Love',
#   'Public Arts',
#   'Thu, 27 Jun 2019 /',
#   43],
#  ['rRoxymore, Working Women, The Funky Seshwa x Crew Love',
#   'Good Room',
#   'Thu, 27 Jun 2019 /',
#   13],
#  ['ReSolute w Alexandra', 'TBA - New York', 'Thu, 27 Jun 2019 /', 8],
#  ['Room 234: 88 Palms (Live) + Kristine Barilli + Ria Bird',
#   'The Sultan Room',
#   'Thu, 27 Jun 2019 /',
#   2],
#  ['Vitamins: Florian Kupfer, Entro Senestre, Amelia Holt, Hidden Prism',
#   'Mood Ring',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Agenda World Pride 101',
#   'Bossa Nova Civic Club',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Synergy 3.0', 'Jupiter Disco', 'Thu, 27 Jun 2019 /', nan],
#  ['Tarek Atoui: Organ Within', 'Guggenheim Museum', 'Thu, 27 Jun 2019 /', nan],
#  ['Toucan Sounds presents Justin Strauss, Haruka, and More',
#   'Black Flamingo',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Hi-Five with Ryan King', 'H0L0', 'Thu, 27 Jun 2019 /', nan],
#  ['Vinyl Please. with Alexkid, KO. b2b Emma',
#   'TBA Brooklyn',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Dirty Thursday: Born This Way', 'House Of Yes', 'Thu, 27 Jun 2019 /', nan],
#  ['Electric Kitchen', 'Hilo', 'Thu, 27 Jun 2019 /', nan],
#  ['Bonus Beats: L&l&l Record Club', 'Le Bain', 'Thu, 27 Jun 2019 /', nan],
#  ['Come One, Come Ally', 'The Woods', 'Thu, 27 Jun 2019 /', nan],
#  ['Brooklyn Record Exchange Residency with Spicy Boys',
#   'Elsewhere',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['The Launch', 'The William Vale', 'Thu, 27 Jun 2019 /', nan],
#  ['Select Vibes', 'Paradise Club', 'Thu, 27 Jun 2019 /', nan],
#  ['yes&yay Pres: The Den - Israel Escobar, Niichavo, Resy',
#   'Macao Trading Company',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Milford Graves: Music Meets Medicine and Science',
#   "Gavin Brown's Enterprise",
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Wythe Hotel X Trevorshaus present Permanent Water: A Pride Celebration',
#   'Wythe Hotel',
#   'Thu, 27 Jun 2019 /',
#   nan],
#  ['Ooze + The Bunker presents Marcel Dettmann (Extended Set)',
#   'TBA - Brooklyn',
#   'Fri, 28 Jun 2019 /',
#   266],
#  ['Ladyland Festival - World Pride 2019 (Friday)',
#   'Brooklyn Mirage',
#   'Fri, 28 Jun 2019 /',
#   200],
#  ['PAPI JUICE Vol. 47: World Pride', 'Elsewhere', 'Fri, 28 Jun 2019 /', 57],
#  ['Glitterbox NYC Pride', 'House Of Yes', 'Fri, 28 Jun 2019 /', 48],
#  ['Friday: Eamon Harkin, DJ Python and Yu Su',
#   'Nowadays',
#   'Fri, 28 Jun 2019 /',
#   29],
#  ['Heartbreaker Pride 2019', 'Good Room', 'Fri, 28 Jun 2019 /', 28],
#  ['Access presents Klaudia Gawlas: Ace Alvarez: Diego Garcia: Dj Ro',
#   'Analog Brooklyn',
#   'Fri, 28 Jun 2019 /',
#   24],
#  ['Firebeatz Boat Party', 'Pier 15', 'Fri, 28 Jun 2019 /', 24],
#  ['/ˈprimədiv/ presents Exos, Jonathan Rosa, Mir Omar, Lightbath',
#   'TBA Brooklyn',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Ascend: The Scumfrog & Special Guests by The Sonic Jungle',
#   'The Williamsburg Hotel',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Delano Smith presents Mixmode / bilaliwood / Miss Sabado - Air',
#   'Bogart House',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['All Night with Amelia Holt + Alejandra Sabillon + DJ Lita',
#   'The Sultan Room',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ["D'Noir AM feat. Christina Crossin, Toranzie",
#   'Polygon BK',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Horse Meat Disco - New York World Pride 2019',
#   'Knockdown Center',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Elixir Pride', 'Mood Ring', 'Fri, 28 Jun 2019 /', nan],
#  ['Butt Disco presents: Fanny Pack', 'Concept', 'Fri, 28 Jun 2019 /', nan],
#  ['Horse Meat Disco NYC Pride w/ Steffi, Aurora Halal',
#   'BASEMENT',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Fokus Pres: Skulptor, Dee Diggs, Heidi Sabertooth',
#   'public records',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Tarek Atoui: Organ Within', 'Guggenheim Museum', 'Fri, 28 Jun 2019 /', nan],
#  ['Charmaine Lee: Laminals II with Victoria Shen',
#   'Issue Project Room',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Select Summer Fridays', 'Le Bain', 'Fri, 28 Jun 2019 /', nan],
#  ['Schimanski presents: Nothing But Beats',
#   'Schimanski',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Wolf Eyes, Stuyedeyed, New Myths', 'Sunnyvale', 'Fri, 28 Jun 2019 /', nan],
#  ['¡NEW YORK iS SPiNNiNG!', 'Trans Pecos', 'Fri, 28 Jun 2019 /', nan],
#  ["Don't Stop The Music Midnight Yacht Cruise",
#   'Harbor Lights Yacht',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Saladin', 'Studio 54, Buffalo/Rochester', 'Fri, 28 Jun 2019 /', nan],
#  ['Alternative Electronic Music 13',
#   'The Other Side',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['6th Annual Float On Yacht Party Tainted Love Tasting',
#   'Skyport Marina',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['//Dreamlands\\\\ 2 Nights of Sensorial Audiovisual Experiences',
#   'Ideal Glass (W 8th)',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ["Tonight's Special with Devin Dare", 'Rose Gold', 'Fri, 28 Jun 2019 /', nan],
#  ['Synthicide presents Void Vision, Bustie, Dead Husband',
#   'Brooklyn Bazaar',
#   'Fri, 28 Jun 2019 /',
#   nan],
#  ['Babygirl JT Almon', 'Black Flamingo', 'Fri, 28 Jun 2019 /', nan],
#  ['Italomatic: Rok One & Facets', 'The Breakers', 'Fri, 28 Jun 2019 /', nan],
#  ['Hopper Hamza Get Down', 'Studio 151', 'Fri, 28 Jun 2019 /', nan],
#  ['Unter Christopher Street', 'TBA - Brooklyn', 'Sat, 29 Jun 2019 /', 577],
#  ['Wrecked & Carry Nation Present an Out of this World Pride w/ Alinka & Shaun J Wright & More',
#   'Elsewhere',
#   'Sat, 29 Jun 2019 /',
#   208],
#  ['Yours Truly, presents: Acid Pauli + more',
#   '99 Scott Ave',
#   'Sat, 29 Jun 2019 /',
#   93],
#  ['Crew Love; Summer Series', 'Industry City', 'Sat, 29 Jun 2019 /', 83],
#  ['SCI+TEC: Dubfire, Juan Maclean, Dave P',
#   'Knockdown Center',
#   'Sat, 29 Jun 2019 /',
#   81],
#  ['Kuná Sunset Rooftop: David Hohme, Sander, Isa, Oktave & Mashrik',
#   'The Williamsburg Hotel',
#   'Sat, 29 Jun 2019 /',
#   81],
#  ['Ladyland Festival - World Pride 2019 (Saturday)',
#   'Brooklyn Mirage',
#   'Sat, 29 Jun 2019 /',
#   75],
#  ['Decatur with Valentino Kanzyani', 'Bogart House', 'Sat, 29 Jun 2019 /', 75],
#  ['Somewhen / Juana / Xiorro', 'BASEMENT', 'Sat, 29 Jun 2019 /', nan],
#  ['Carried Away Boat Party with DJ Vibe',
#   'Circle Line Cruises',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Ladies of LCD Soundsystem Pride Party with Nancy Whang and Gavin Rayna Russom',
#   'Good Room',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Monkey Wrench Techno - Akki / B-Rad / Alex English / DANAE / Remniqe / A DJ Named Sne',
#   'TBA - Brooklyn',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Judy', 'House Of Yes', 'Sat, 29 Jun 2019 /', nan],
#  ['Pride Saturday: New World Dysorder and HIM HUN',
#   'Nowadays',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ["D'Noir AM feat. Christian Smith, Tone Troy",
#   'Polygon BK',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['No Labels: Jaytech, Farius, Lucid Noise & Reznor',
#   'Concept',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Soup Fam', 'TBA', 'Sat, 29 Jun 2019 /', nan],
#  ['Broke City with Relaxer (Live) + Ren G + Deep Creep',
#   'The Sultan Room',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Susanne Bartsch & Dreamhouse present The Ballroom',
#   'Sony Hall',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Cafe con Leche presents World Pride feat. DJs Merritt, Lord G and Rissa Garcia',
#   'Club 51',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Throttle Boat Party - Pre-Independence Day Celebration',
#   'Pier 15',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Nowadays & Sublimate Pride BBQ', 'Nowadays', 'Sat, 29 Jun 2019 /', nan],
#  ['Funky Sensation with François K', 'Le Bain', 'Sat, 29 Jun 2019 /', nan],
#  ['Iron Curtis + Map.Ache', 'public records', 'Sat, 29 Jun 2019 /', nan],
#  ['Orphan. presents Reckonwrong, DJ Voices & Joey G ii b2b Klein Zage',
#   'H0L0',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['The Secret Art of Science feat. DB',
#   'public records',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Charmaine Lee: Laminals II with Victoria Shen',
#   'Issue Project Room',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Select Summer Fridays', 'Le Bain', 'Sat, 29 Jun 2019 /', nan],
#  ['The Secret Art of Science', 'public records', 'Sat, 29 Jun 2019 /', nan],
#  ['The Roof By Sabr.House', 'The Roof', 'Sat, 29 Jun 2019 /', nan],
#  ['Schimanski presents: Mason Maynard',
#   'Schimanski',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Epic Night', 'Club 57', 'Sat, 29 Jun 2019 /', nan],
#  ['Half Moon', 'Bossa Nova Civic Club', 'Sat, 29 Jun 2019 /', nan],
#  ['ANTES', 'The Water Tower Bar', 'Sat, 29 Jun 2019 /', nan],
#  ['Barba Party [NYC World Pride Edition]',
#   '3 Dollar Bill',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['6th Annual Float On Yacht Party Tainted Love Tasting',
#   'Skyport Marina',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['//Dreamlands\\\\ 2 Nights of Sensorial Audiovisual Experiences',
#   'Ideal Glass (W 8th)',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Trade: Gaywatch // NYC World Pride',
#   'The Deep end',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Microtones: Russell E.L. Butler',
#   'Forest City Lodge 180',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Groove Lab Showcase Feat. Vidur, Jahaan & Lea',
#   'Ms. Yoo',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Yalla! دايك', 'Bryant Park', 'Sat, 29 Jun 2019 /', nan],
#  ['Assembly: Lafawndah, NAR, Angie Pittman',
#   'The Kitchen',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Secret Friend 007', 'Black Flamingo', 'Sat, 29 Jun 2019 /', nan],
#  ['History Of Heat - SADAF Release Party',
#   'Sister City',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['The Asmbly Welcomes Recloose & Donnis',
#   'Rose Gold',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ["Brunch N' Beats 2019 Summer Residency NYC",
#   'Highbar NYC',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['Makossa BK Cookout (wsg Khalil, Jadalareign, & Haylow)',
#   'Our Wicked Lady',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['The Rub', 'The Bell House', 'Sat, 29 Jun 2019 /', nan],
#  ['Sasha Barbot / Mangusto', 'Paradise Club', 'Sat, 29 Jun 2019 /', nan],
#  ['Diving for Disco **Rooftop** with Jake From Extra Water',
#   'Our Wicked Lady',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['New York Pride Fest', 'Sunnyvale', 'Sat, 29 Jun 2019 /', nan],
#  ['[CANCELLED] Industry of Machines presents: World Pride Day',
#   'TBA - Brooklyn',
#   'Sat, 29 Jun 2019 /',
#   nan],
#  ['718 Sessions Boat Party 2019',
#   'Circle Line Cruises',
#   'Sun, 30 Jun 2019 /',
#   153],
#  ['Mister Sunday Pride: FNV and Lex Rodriguez',
#   'Nowadays',
#   'Sun, 30 Jun 2019 /',
#   109],
#  ['ReSolute & Knockdown Center present: Tini & DeWalta',
#   'Knockdown Center',
#   'Sun, 30 Jun 2019 /',
#   103],
#  ['Love Injection with Paul and Barbie',
#   'public records',
#   'Sun, 30 Jun 2019 /',
#   23],
#  ['Proud AF: Pride March Afterparty',
#   'House Of Yes',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Tiki Disco (Elsewhere Rooftop)', 'Elsewhere', 'Sun, 30 Jun 2019 /', nan],
#  ['World Pride 2019 Feat. Loud & Proud Tour After Party',
#   'Pier 15',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Paradisco Pride', 'Le Bain', 'Sun, 30 Jun 2019 /', nan],
#  ['Drip: Pride (w/ Ostgut Ton Special Guest, KVN, Ren G, Night Doll, zoomscua)',
#   'Bossa Nova Civic Club',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Birdcage World Pride Edition', 'Le Bain', 'Sun, 30 Jun 2019 /', nan],
#  ['Assembly: Jason Moran, Logan Takahashi, Wetware',
#   'The Kitchen',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Help UR Self with Five + Toribio + DJ Bruce',
#   'The Sultan Room',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Sunday Soiree: Cape, Arvi', 'TBA Brooklyn', 'Sun, 30 Jun 2019 /', nan],
#  ['Yalla! دايك', 'Bryant Park', 'Sun, 30 Jun 2019 /', nan],
#  ['World Pride JOY. A Day Party In Brooklyn',
#   'The Well',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ["Louie Devito's NYC Underground Party",
#   "The Water Club @ Pop's",
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['8 Ball Community presents: The American Dream with Riich Psycho, Sporting Life, and More',
#   'Rubulad',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Post Pride Parade After Party on a Club Yacht',
#   'Hornblower Cruise',
#   'Sun, 30 Jun 2019 /',
#   nan],
#  ['Fermented Frequency', 'Bossa Nova Civic Club', 'Mon, 01 Jul 2019 /', 4],
#  ['Jamais Vu presents Sagotsky (Sublimate) / Son of Lee (Dailysession) / Serrian (Jamais Vu)',
#   'Jupiter Disco',
#   'Mon, 01 Jul 2019 /',
#   1]]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net" + url_ext
    #Your code here
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
dfs = []
total_rows = 0
cur_url = "https://www.residentadvisor.net/events/us/newyork"
while total_rows <= 1000:
    df = scrape_events(cur_url)
    dfs.append(df)
    total_rows += len(df)
    cur_url = next_page(cur_url)
df = pd.concat(dfs)
df = df.iloc[:1000]
print(len(df))
df.head()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-103-fbf19e8ff1c7> in <module>()
#       7     dfs.append(df)
#       8     total_rows += len(df)
# ----> 9     cur_url = next_page(cur_url)
#      10 df = pd.concat(dfs)
#      11 df = df.iloc[:1000]
#
# <ipython-input-73-43a29f3f2c13> in next_page(url)
#       2     response = requests.get(url)
#       3     soup = BeautifulSoup(response.content, 'html.parser')
# ----> 4     url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
#       5     next_page_url = "https://www.residentadvisor.net" + url_ext
#       6     #Your code here
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
